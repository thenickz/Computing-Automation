# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# resolvendo agora para runge kutta 2
# primeiro com h valendo 0.5
h1 = 0.5
t_final = 2
n1 = int(t_final/h1) + 1

# criando os arrays de zeros
t1 = [0 for _ in range(n1)]
y1 = [0 for _ in range(n1)]

# definindo condições iniciais
y1[0] = 1
t1[0] = 0

# método de runge kutta 2 para h de 0.5
for k in range(1, n1):
    t1[k] = t1[k-1] + h1 
    k1 = y1[k-1] * (t1[k-1]**2)
    k2 = (y1[k-1] + h1*k1) * ((t[k-1] + h1)**2)
    y[k] = y[k-1] + h1*(k1 + k2)/2

# agora preparar para plotar no gráfico o que foi calculado
# na cor vermelha e pontilhada
plt.plot(t1, y1, color='red', label = 'runge kutta 2 para h= 0.5', linestyle='dotted')

# %%
# agora com h valendo 0.25
# configurando novas variáveis
h2 = 0.25
n2 = int(t_final/h2) + 1

# recriando os arrays de zero
t2 = [0 for _ in range(n2)]
y2 = [0 for _ in range(n2)]

# definindo condições iniciais
y2[0] = 1
t2[0] = 0

# método de runge kutta 2 para h de 0.25
for i in range(1, n2):
    t2[i] = t2[i-1] + h2 
    k1 = y2[i-1] * (t2[i-1]**2)
    k2 = (y2[i-1] + h2*k1) * ((t2[i-1] + h2)**2)
    y2[k] = y2[i-1] + h2*(k1 + k2)/2

# agora preparar para plotar no gráfico o que foi calculado
# na cor azul e tracejada
plt.plot(t2, y2, color='blue', label = 'runge kutta 2 para h= 0.25', linestyle='dashed')

# %%
plt.xlabel('Eixo t')
plt.ylabel('Eixo y')
plt.title('Exercício 1')
plt.legend(loc = 'upper left')
plt.grid()
plt.show()
